# %% [markdown]
# <a href="https://colab.research.google.com/github/juandarango/Machine_Learning_Vorlesung/blob/main/DS-ML-PL_Fallstudie_2b_Lösungsvorschlag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Im Colab öffnen"/></a>

# %% [markdown]
# # Fallstudie 2b: Orientierung von Äpfeln
#
# ## Regression von der Rotation

# %% [markdown]
# ## Ziel: Lageerkennung
#
# Die Lageerkennung ist eine Herausforderung für die Deep-Learning Bildverarbeitung, denn um die Drehung eines Objektes im Raum erkennen zu können, benötigt man eine Datenbank mit allen möglichen Drehungen.

# %% [markdown]
# ## Wie kann einen Winkel vorhergesagt werden?
#
# Ein Winkel ist ein kontinuierlicher Wert.
#
# ### Klassifikation:
#     Es wäre möglich Winkeln in klassen zu verteilen. zB:
#     x=10, 20, 30 ...
#     y=10, 20, 30 …
#     und jede mögliche kombinationen von x und y.
#
#    <font color='orange'>Nachteile:</font>
#    * Zu viele Klassen.
#    * Nur diskrete werte wurden auch vorhergesagt
#
# ### Regression:
#
# Alle Werte können vorhergesagt werden. NN haben als output kontinuierlicher Werte, die durch eine softmax funktion in klassen verteilt werden. In diesem Fall wurde diese Schritt ausfallen.

# %% [markdown]
# ## Was soll den Input und Output sein?
# ### Input: Bild mit einem Apfel
#
# Die Bildern wurden semi-automatisch erzeugt.
#  - Schrittmotor + künztliche rotation

# %% [markdown]
# <img src="Photos/stepper.png" style="width:300px">

# %% [markdown]
# Daten:
#  - wie sind die Daten gespeichert?
#  - wie sehen die Bildern aus?

# %% [markdown]
# <img src="Photos/xrot.png" style="width:500px">

# %%
# Fastai in colab installieren (mit version Angabe)
# !pip install -Uqq torch==1.6.0
# !pip install -Uqq torchvision==0.7.0
# !pip install -Uqq fastcore==1.1.0
# !pip install -Uqq fastai==2.0.16
# Fehler Meldungen ignorieren!

# %%
from fastai.vision.all import *

# %%
#Datensatz in Colab montieren
url_photos = 'https://data.ips.biba.uni-bremen.de/Lehre/dsmlpl_SS21/Apples_Reg_all.tgz'
path_apples = untar_data(url_photos)
path_apples.ls().sorted()
# Out:
# (#1) [Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00')]

# %%
path_apples = path_apples/'Apples_Vorlesung_Z_00'
#path_apples=Path('/home/ara/Dokumente/CNN_Python/Vorlesung Deep Learning/Datensatz/Apples_Reg_all/Apples_Vorlesung_Z_00')

# %%
path_apples.ls().sorted()
# Out:
# (#24) [Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_01'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_01seg'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_02'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_02seg'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_03'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_03seg'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04seg'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_05'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_05seg')...]

# %%
path_apples_4 = path_apples/'Apple_04'
apple_4_files = path_apples_4.ls(file_exts='.png').sorted()
apple_4_files
# Out:
# (#36) [Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0000_X_000_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0018_X_180_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0289_X_010_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0290_X_020_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0291_X_030_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0292_X_040_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0293_X_050_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0294_X_060_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0295_X_070_Z_00.png'),Path('/home/ara/.fastai/data/Apples_Reg_all/Apples_Vorlesung_Z_00/Apple_04/0296_X_080_Z_00.png')...]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# select some images to show
apple1 = apple_4_files[0]
apple2 = apple_4_files[3]
apple3 = apple_4_files[6]
apple4 = apple_4_files[9]

fig = plt.figure(figsize=(10,10))
plt.subplot(2, 2, 1)
im = Image.open(apple1)
plt.imshow(im)
plt.title(apple1.name)

plt.subplot(2, 2, 2)
im = Image.open(apple2)
plt.imshow(im)
plt.title(apple2.name)

plt.subplot(2, 2, 3)
im = Image.open(apple3)
plt.imshow(im)
plt.title(apple3.name)

plt.subplot(2, 2, 4)
im = Image.open(apple4)
plt.imshow(im)
plt.title(apple4.name)

plt.show()

# %% [markdown]
# ### Output: Winkel in x,z,y
#
# Ein Apfel ist normalerweise in einem Axis symmetrisch, dann werden nur 2 Axis gebraucht.
#
# Diese Information ist im Name des Bilds gespeichert:
#
# zum Beispiel: 0005_X_055_Z_05.png
#
# - Bildnummer = 0005
# - Winkel in X = 55°
# - Winkel in Z = 5°
#
# Mit 'Regular Expression operations' kann man diese Information herausfinden

# %%
file_name = apple2.name
file_name
# Out:
# '0290_X_020_Z_00.png'

# %%
# Beispiel mit String array info
float(file_name[7:10])
# Out:
# 20.0

# %%
# Beispiel RegEx für X und Z
xz_reg = re.compile(r'X_(-?\d+)_Z_(-?\d+).png$')
x=float(xz_reg.search(str(file_name)).group(1))
z=float(xz_reg.search(str(file_name)).group(2))

x,z
# Out:
# (20.0, 0.0)

# %% [markdown]
# Trotzdem haben Winkeln in Grad große Nachteile für das Trainieren von CNN.
#
# - 0° = 360°
# - kardanische Blockade (Gimbal Lock): In diesem Zustand liegen zwei der möglichen drei Drehachsen parallel zueinander und das System hat dadurch einen Freiheitsgrad weniger.(s. https://www.youtube.com/watch?v=kHFwysRM2ps)
#
# Deswegen werden oft Quaternionen benutzt.

# %%
def simple_get_y(file_name):
    '''return only X as float from the file_name'''
    xz_reg = re.compile(r'X_(-?\d+)_Z_(-?\d+).png$')
    x=float(xz_reg.search(str(file_name)).group(1))
    z=float(xz_reg.search(str(file_name)).group(2))
    return x

simple_get_y(file_name)
# Out:
# 30.0

# %% [markdown]
# An sich ist ein DataBlock in Fastai nur eine Vorlage, um die Daten zusammenzustellen.
#
# Normalerweise wird den DataBlock aufgebaut, indem die Folgende Fragen beantwortet werden:
#
# - Datatyp von Inputs und Outputs? Hier Bilder und Nummern
# - wo befinden sich die Daten? Hier in Dateinamen in Unterordnern
# - muss etwas auf die Inputs angewendet werden? Hier nein
# - muss etwas auf die Outputs angewandt werden? Hier die Funktion get_y
# - wie werden die Daten aufgeteilt? Hier zufällig
# - müssen wir etwas auf geformte Elemente anwenden? Hier eine Größenänderung (Resize)
# - müssen wir etwas auf batch_transformations anwenden? Hier keine
#
# Damit kann ein dataloader erstellt werden. Dies erhalt die Training und Validation Datenseztse, um die CNN zu trainieren!

# %%
path = path_apples
dblock = DataBlock(blocks=(ImageBlock, RegressionBlock),
                   splitter  = RandomSplitter(valid_pct=0.2,seed=77),
                   get_items = get_image_files,
                   get_y = simple_get_y,#nur z
                   item_tfms = Resize(190),
                  )

dls = dblock.dataloaders(path)

# %%
dls.valid_ds,dls.train_ds
# Out:
# ((#4359) [(PILImage mode=RGB size=190x190, tensor(190.)),(PILImage mode=RGB size=193x192, tensor(130.)),(PILImage mode=RGB size=190x190, tensor(200.)),(PILImage mode=RGB size=190x190, tensor(160.)),(PILImage mode=RGB size=198x202, tensor(180.)),(PILImage mode=RGB size=262x259, tensor(280.)),(PILImage mode=RGB size=190x190, tensor(225.)),(PILImage mode=RGB size=300x300, tensor(100.)),(PILImage mode=RGB size=300x300, tensor(330.)),(PILImage mode=RGB size=300x300, tensor(90.))...],
#  (#17437) [(PILImage mode=RGB size=241x221, tensor(185.)),(PILImage mode=RGB size=232x234, tensor(190.)),(PILImage mode=RGB size=300x300, tensor(220.)),(PILImage mode=RGB size=190x190, tensor(280.)),(PILImage mode=RGB size=190x190, tensor(85.)),(PILImage mode=RGB size=190x190, tensor(195.)),(PILImage mode=RGB size=300x300, tensor(300.)),(PILImage mode=RGB size=300x300, tensor(30.)),(PILImage mode=RGB size=190x190, tensor(170.)),(PILImage mode=RGB size=300x300, tensor(90.))...])

# %%
dls.train_ds[0:5]
# Out:
# [(PILImage mode=RGB size=241x221, tensor(185.)),
#  (PILImage mode=RGB size=232x234, tensor(190.)),
#  (PILImage mode=RGB size=300x300, tensor(220.)),
#  (PILImage mode=RGB size=190x190, tensor(280.)),
#  (PILImage mode=RGB size=190x190, tensor(85.))]

# %%
dls.show_batch(max_n=6)

# %%
MSELossFlat??
nn.MSELoss??
F.mse_loss??

# %%
def mean_square_sin_error(inp,targ): 
    '''mean absolute from the sin of the error/2'''
    inp,targ = flatten_check(inp,targ)
    return torch.square(torch.sin((inp-targ)/2*np.pi/180)).mean()

# %%
def mean_absolute_sin_error(inp,targ): 
    '''mean absolute from the sin of the error/2'''
    inp,targ = flatten_check(inp,targ)
    return torch.abs(torch.sin((inp-targ)/2*np.pi/180)).mean()

# %%
p1,p2=tensor(5.),tensor(360.)

mae(p1,p2)*np.pi/180 #in rad
# Out:
# tensor(6.1959)

# %%
mean_absolute_sin_error(p1,p2)
# Out:
# tensor(0.0436)

# %%
angle_diff = np.arange(-360,360)
y = np.square(np.sin((angle_diff)/2*np.pi/180))
plt.plot(angle_diff,y)

# %%
def mae2(inp,targ):
    "Mean absolute error between `inp` and `targ`."
    inp,targ = flatten_check(inp,targ)
    return torch.abs(((inp - targ)+180)%360-180).mean()

# %%
a = 360 - 6
a = (a + 180) % 360 - 180
a
# Out:
# -6

# %%
learn = cnn_learner(dls,resnet34,pretrained=True,metrics=(mae2),loss_func=mean_square_sin_error)

# %% [markdown]
# Input von cnn_learner:
#
# - dls: Wir benutzen die Daten auf dem Dataloader
# - Transfer learning: Wir benutzen eine vortranierte CNN (resnet34,pretrained=True)
# - Metrics: Wir werden beobachten ob den mae (mean absolute error) besser wird.

# %%
#Andere parametern sind als dafault konfiguriert
learn.opt_func
# Out:
# <function fastai.optimizer.Adam(params, lr, mom=0.9, sqr_mom=0.99, eps=1e-05, wd=0.01, decouple_wd=True)>

# %%
learn.loss_func
# Out:
# <function __main__.mean_square_sin_error(inp, targ)>

# %% [markdown]
# ##  Training: Learning Rate Finder (Fastai)
#
# Es werden kleine batches benutzt, und mit verschiedenen LRs traniert. Das plotten von den Losses soll die LR-Entscheidung einfacher machen:

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.09120108485221863, lr_steep=0.033113110810518265)

# %% [markdown]
# Wir benutzen einen Wert zwischen lr_min und lr_steep

# %%
learn = cnn_learner(dls,resnet34,pretrained=True,metrics=(mae2),loss_func=mean_square_sin_error)
lr=1e-2
learn.fine_tune(10,lr,5)
#learn.fit_one_cycle(10,lr)
learn.recorder.plot_loss(skip_start=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.290899</td>
#       <td>0.222263</td>
#       <td>48.639927</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.149074</td>
#       <td>0.114924</td>
#       <td>30.822218</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.098969</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-fb7f1b380328> in <module>
#       1 learn = cnn_learner(dls,resnet34,pretrained=True,metrics=(mae2),loss_func=mean_square_sin_error)
#       2 lr=1e-2
# ----> 3 learn.fine_tune(10,lr,5)
#       4 #learn.fit_one_cycle(10,lr)
#       5 learn.recorder.plot_loss(skip_start=10)
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/logargs.py in _f(*args, **kwargs)
#      54         init_args.update(log)
#      55         setattr(inst, 'init_args', init_args)
# ---> 56         return inst if to_return else f(*args, **kwargs)
#      57     return _f
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/callback/schedule.py in fine_tune(self, epochs, base_lr, freeze_epochs, lr_mult, pct_start, div, **kwargs)
#     159     "Fine tune with `freeze` for `freeze_epochs` then with `unfreeze` from `epochs` using discriminative LR"
#     160     self.freeze()
# --> 161     self.fit_one_cycle(freeze_epochs, slice(base_lr), pct_start=0.99, **kwargs)
#     162     base_lr /= 2
#     163     self.unfreeze()
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/logargs.py in _f(*args, **kwargs)
#      54         init_args.update(log)
#      55         setattr(inst, 'init_args', init_args)
# ---> 56         return inst if to_return else f(*args, **kwargs)
#      57     return _f
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt)
#     111     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     112               'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 113     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#     114
#     115 # Cell
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/logargs.py in _f(*args, **kwargs)
#      54         init_args.update(log)
#      55         setattr(inst, 'init_args', init_args)
# ---> 56         return inst if to_return else f(*args, **kwargs)
#      57     return _f
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     205             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     206             self.n_epoch = n_epoch
# --> 207             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     208
#     209     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _do_fit(self)
#     195         for epoch in range(self.n_epoch):
#     196             self.epoch=epoch
# --> 197             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     198
#     199     @log_args(but='cbs')
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _do_epoch(self)
#     189
#     190     def _do_epoch(self):
# --> 191         self._do_epoch_train()
#     192         self._do_epoch_validate()
#     193
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _do_epoch_train(self)
#     181     def _do_epoch_train(self):
#     182         self.dl = self.dls.train
# --> 183         self._with_events(self.all_batches, 'train', CancelTrainException)
#     184
#     185     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in all_batches(self)
#     159     def all_batches(self):
#     160         self.n_iter = len(self.dl)
# --> 161         for o in enumerate(self.dl): self.one_batch(*o)
#     162
#     163     def _do_one_batch(self):
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in one_batch(self, i, b)
#     177         self.iter = i
#     178         self._split(b)
# --> 179         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     180
#     181     def _do_epoch_train(self):
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
# --> 157         finally:   self(f'after_{event_type}')        ;final()
#     158
#     159     def all_batches(self):
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in __call__(self, event_name)
#     131     def ordered_cbs(self, event): return [cb for cb in sort_by_run(self.cbs) if hasattr(cb, event)]
#     132
# --> 133     def __call__(self, event_name): L(event_name).map(self._call_one)
#     134
#     135     def _call_one(self, event_name):
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/foundation.py in map(self, f, gen, *args, **kwargs)
#     308         res = map(g, self)
#     309         if gen: return res
# --> 310         return self._new(res)
#     311
#     312     def filter(self, f=noop, negate=False, gen=False, **kwargs):
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/foundation.py in _new(self, items, *args, **kwargs)
#     252     @property
#     253     def _xtra(self): return None
# --> 254     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
#     255     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     256     def copy(self): return self._new(self.items.copy())
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/foundation.py in __call__(cls, x, *args, **kwargs)
#     233     def __call__(cls, x=None, *args, **kwargs):
#     234         if not args and not kwargs and x is not None and isinstance(x,cls): return x
# --> 235         return super().__call__(x, *args, **kwargs)
#     236
#     237 # Cell
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/foundation.py in __init__(self, items, use_list, match, *rest)
#     243         if items is None: items = []
#     244         if (use_list is not None) or not _is_array(items):
# --> 245             items = list(items) if use_list else _listify(items)
#     246         if match is not None:
#     247             if is_coll(match): match = len(match)
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/foundation.py in _listify(o)
#     119     if isinstance(o, list): return o
#     120     if isinstance(o, str) or _is_array(o): return [o]
# --> 121     if is_iter(o): return list(o)
#     122     return [o]
#     123
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastcore/foundation.py in __call__(self, *args, **kwargs)
#     182             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     183         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 184         return self.fn(*fargs, **kwargs)
#     185
#     186 # Cell
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in _call_one(self, event_name)
#     135     def _call_one(self, event_name):
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#     139     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in <listcomp>(.0)
#     135     def _call_one(self, event_name):
#     136         assert hasattr(event, event_name), event_name
# --> 137         [cb(event_name) for cb in sort_by_run(self.cbs)]
#     138
#     139     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/callback/core.py in __call__(self, event_name)
#      42                (self.run_valid and not getattr(self, 'training', False)))
#      43         res = None
# ---> 44         if self.run and _run: res = getattr(self, event_name, noop)()
#      45         if event_name=='after_fit': self.run=True #Reset self.run to True at each end of fit
#      46         return res
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in after_batch(self)
#     451         if len(self.yb) == 0: return
#     452         mets = self._train_mets if self.training else self._valid_mets
# --> 453         for met in mets: met.accumulate(self.learn)
#     454         if not self.training: return
#     455         self.lrs.append(self.opt.hypers[-1]['lr'])
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/learner.py in accumulate(self, learn)
#     402     def accumulate(self, learn):
#     403         self.count += 1
# --> 404         self.val = torch.lerp(to_detach(learn.loss.mean(), gather=False), self.val, self.beta)
#     405     @property
#     406     def value(self): return self.val/(1-self.beta**self.count)
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/torch_core.py in to_detach(b, cpu, gather)
#     216         if gather: x = maybe_gather(x)
#     217         return x.cpu() if cpu else x
# --> 218     return apply(_inner, b, cpu=cpu, gather=gather)
#     219
#     220 # Cell
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/torch_core.py in apply(func, x, *args, **kwargs)
#     196     if is_listy(x): return type(x)([apply(func, o, *args, **kwargs) for o in x])
#     197     if isinstance(x,dict):  return {k: apply(func, v, *args, **kwargs) for k,v in x.items()}
# --> 198     res = func(x, *args, **kwargs)
#     199     return res if x is None else retain_type(res, x)
#     200
#
# ~/anaconda3/envs/fastai2020/lib/python3.8/site-packages/fastai/torch_core.py in _inner(x, cpu, gather)
#     215         x = x.detach()
#     216         if gather: x = maybe_gather(x)
# --> 217         return x.cpu() if cpu else x
#     218     return apply(_inner, b, cpu=cpu, gather=gather)
#     219
#
# KeyboardInterrupt:

# %% [markdown]
# Sehr gut, mein Netz hat etwas gelernt!
# - Aber ist das gut?
# - Wie kann ich es beurteilen?
# - Wie kann ich es testen?

# %% [markdown]
# wir können learn.show_results() benutzen

# %%
learn.show_results()

# %%
preds,target = learn.get_preds(ds_idx=1)
preds=preds%360
preds[0:5],target[0:5]

# %%
error=np.asarray(preds).reshape(-1)-np.asarray(target)
error=(error + 180) % 360 - 180
abs_error = np.abs(error)
np.mean(abs_error)

# %%
top_wrong=np.flip(np.argsort(abs_error)) #sort index from biggest error to smallest error
most_wrong=top_wrong[0]
top_wrong[0:5]

# %%
# Image from the validation dataset:
most_wrong=top_wrong[2]
valid_image = dls.valid_ds[most_wrong][0]
valid_image.show()
dls.valid_ds[most_wrong][1],learn.predict(valid_image)

# %%
# plot real value vs predicted value
plt.subplots_adjust(wspace=0.6,hspace=0.6);
plt.figure(figsize=(10,10)) ;
plt.subplot(211)
plt.scatter(target, preds);
plt.title('X Rotation')
plt.xlabel('Real angle')
plt.ylabel('Prediction for angle in degrees')
plt.grid()

plt.subplot(212)
plt.hist(abs_error,36);
plt.title('Absolute Error histogram aroud X')
plt.xlabel('Error value in degrees')
plt.ylabel('Nr of errors')
plt.grid();

# %%
# Wir machen eine Funktion daraus
def my_interpreter(learn,ds_idx=1):
    preds,target = learn.get_preds(ds_idx=1)
    error=np.asarray(preds).reshape(-1)-np.asarray(target)
    error=(error + 180) % 360 - 180
    abs_error = np.abs(error)
    # plot real value vs predicted value
    plt.subplots_adjust(wspace=0.6,hspace=0.6);
    plt.figure(figsize=(10,10)) ;
    plt.subplot(211)
    plt.scatter(target, preds);
    plt.title('X Rotation')
    plt.xlabel('Real angle')
    plt.ylabel('Prediction for angle in degrees')
    plt.grid()
    # plot error histogram
    plt.subplot(212)
    plt.hist(abs_error,36);
    plt.title('Absolute Error histogram aroud X')
    plt.xlabel('Error value in degrees')
    plt.ylabel('Nr of errors')
    plt.grid()
    print('mean absolute error = ',np.mean(abs_error))
    return np.flip(np.argsort(abs_error))

# %% [markdown]
# ## Super! Es klappt richtig gut!
#
# jetzt soll man auch mit anderen Bildern testen

# %%
#test_path = Path()/'../../Testset'
url_photos = 'https://data.ips.biba.uni-bremen.de/Lehre/dsmlpl_SS21/Apples_Test.tgz'
test_path = untar_data(url_photos)
#test_path = Path('/home/ara/Dokumente/CNN_Python/Vorlesung Deep Learning/Datensatz/Apple_20_Test')
test_path.ls()

# %%
test_dblock_190 = DataBlock(blocks=(ImageBlock, RegressionBlock),
                   splitter  = RandomSplitter(valid_pct=0.9,seed=7),
                   get_items = get_image_files,
                   get_y = simple_get_y,
                   item_tfms = Resize(190), 
                  )




test_dls_190 = test_dblock_190.dataloaders(test_path,bs=2)
test_dls_190.show_batch()

# %%
learn.dls = test_dls_190

# %%
my_interpreter(learn);

# %% [markdown]
# ## Wir haben ein Problem! Mit test Daten geht es nicht wie erwartet!

# %% [markdown]
# ## Warum ist die unterschied zwischen Validierungsfehler und Testfehler so groß?
#
# ### 1. Poblem: Die Bilder im Validierungs- und Trainings-Set sind praktisch gleich.
# Da die Bildern zufällig ausgewählt sind und nur wenige Winkel gedreht sind, sind Äpfel im Validierungs- und Trainings-Set praktisch gleich. Aus diesem Grund scheint es, als ob das Netzwerk perfekt funktioniert, aber in Wirklichkeit hat das Netz genau den Winkel diesen 20 Äpfel zu unterscheiden und nicht andere Äpfel.
#
# ### 1. Lösung: Unterschiedliche Äpfel für den Trainings- und Validierungssatz.
#
# Verschiedene Äpfel für das Training und Validierung verwenden, damit die CNN besser verallgemeinen können. z. B. die ersten 15 Äpfel zum Trainieren und die letzten 5 Äpfel zum Validieren verwenden.

# %%
path_apples.ls()
train=[Path(x).name for x in path_apples.ls() if Path(x).name[7]!='7']
val=[Path(x).name for x in path_apples.ls() if Path(x).name[7]=='7']
val

# %%
dblock2 = DataBlock(blocks=(ImageBlock, RegressionBlock),
                   splitter  = FuncSplitter(lambda o: Path(o).parent.name[7]=='7'),
                   get_items = get_image_files,
                   get_y = simple_get_y,
                   item_tfms = Resize(190),
                  )

dls2 = dblock2.dataloaders(path_apples)

# %%
dls2.valid_ds, dls2.train_ds

# %%
dls2.show_batch(max_n=3)

# %%
learn2 = cnn_learner(dls2,resnet34,pretrained=True,metrics=(mae2),loss_func=mean_square_sin_error)

# %%
learn2.lr_find()

# %%
lr = 1e-2
learn2.fit_one_cycle(5,lr)
learn2.recorder.plot_loss(skip_start=10)

# %% [markdown]
# unsere Netze können nicht mehr so einfach lernen!
# Das ist aber gut, die Bilder können nicht mehr auswendig gelernt werden!

# %% [markdown]
# ### Fine-Tunning ohne fine_tune()
#
# mit der .fit und .fit_one_cycle waren fast alle die gewichte von unsere CNN gefroren, bzw. konnten nicht aktualisiert werden. Nur die Parametern in dem letzten Layer wurden angepasst.
#
# Mit fine-tuning können auch die letze Layers traniert werden.

# %%
learn2.unfreeze()

# %%
learn2.lr_find()

# %%
 learn2.fit_one_cycle(5,lr_max=slice(5e-6,5e-4))

# %%
learn2.save('rnet34_190px')
#learn2.load('rnet34_90px')

# %%
my_interpreter(learn2)

# %% [markdown]
# da die Daten nicht mehr fast gleich sind, können diese netze nicht besser werden

# %% [markdown]
# ### Jetzt testen wir nochmal

# %%
learn2.dls = test_dls_190

# %%
my_interpreter(learn2);

# %% [markdown]
# Das ist besser, aber der Fehler ist noch zu groß!

# %% [markdown]
# ## Wie kann ich besser werden?
# ### Problem: Die Erkennung ist nicht robust
# ### Lösung: Data-Augmentation
# Data augmentation mit fastai: https://docs.fast.ai/vision.augment.html

# %%
dblock2_big_aug= DataBlock(blocks=(ImageBlock, RegressionBlock),
                   splitter  =FuncSplitter(lambda o: Path(o).parent.name[7]=='7'),
                   get_items = get_image_files,
                   get_y = simple_get_y, 
                   item_tfms = Resize(190),
                   batch_tfms=[*aug_transforms(size=190,do_flip=False,flip_vert=False,max_rotate=0)]
                  )

dls2_big_aug = dblock2_big_aug.dataloaders(path_apples)


dls2_big_aug.show_batch()

# %%
learn2.dls = dls2_big_aug
learn2.lr_find()

# %%
lr=1e-3
learn2.fine_tune(3,lr,1)
learn2.recorder.plot_loss()

# %%
my_interpreter(learn2);

# %% [markdown]
# ### Jetzt testen wir nochmal

# %%
learn2.dls = test_dls_190

# %%
my_interpreter(learn2);

# %% [markdown]
# es ist nicht perfekt, aber es ist viel besser geworden!

# %% [markdown]
# ## Weitere mögliche Verbesserungen:
# - Mehr Daten: echte Daten Verwenden aus unterschiedliche Äpfelsorten.
# - Weitere state-of-the-art Netze testen
# - Neue Optimizers, neue nicht liniare Funktionen (z.B. Mish anstatt Relu), und weitere coole sachen!

# %%
learn3 = cnn_learner(dls2_big_aug,??,pretrained=True,metrics=(mae2),
                     loss_func=mean_square_sin_error,opt_func=??,wd=??)
learn3.lr_find()
